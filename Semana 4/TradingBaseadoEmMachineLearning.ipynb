# %% [markdown]
# # Trading Baseado em Machine Learning
#
# Machine Learning é a combinação entre a ciência e a arte de programar computadores para que possam aprender com os dados.
#
# A aprendizagem nesse contexto significa identificar padrões complexos dos dados.
#
# O machine learning pode possuir característica de ser uma:
# - Aprendizagem supervisionado: possui como propósito a classificação e a regressão;
# - Aprendizagem não supervisionado: possui como propósito a agrupação(clustering) e redução de dimensão;
#
# ## Aprendizagem supervisionada
# ### Classificação
# Buscam predizer se uma observação pertence a uma determinada categoria.
#
# No caso dos algoritmos de negociação, podemos prognosticar se um preço vai subir ou descer com base no histórico desse ativo.
#
# Os principais algoritmos de classificação são:
# - Regressão logística;
# - Máquinas de suportes vetoriais;
# - Árvores de classificação;
# - Redes neurais.
#
# ### Regressão
# Buscam predizer uma variável de saída baseado em um conjunto de dados.
#
# No caso de algoritmos de negociação, poderíamos aplicar um modelo de regressão treinado com o histórico do ativo para predizer o preço futuro.
#
# Alguns algoritmos de regressão são:
# - Regressões lineares;
# - Séries de tempos;
# - Máquinas de suportes vetoriais;
# - Árvores de decisões;
# - Redes neurais.
#
# ## Aprendizagem não supervisionada
#
# ### Agrupamentos(clustering)
#
# Buscam encontrar padrões ocultos e agrupamentos (cluster) dentro dos dados.
#
# No caso de algoritmos de negociação, poderíamos aplicar o clustering para auxiliar no investimento a longo prazo para empresas de um determinado mercado. Em outras palavras, os algoritmos de clustering buscaram padrões ocultos para segmentar grupos de determinadas empresas para selecionar em qual investir.
#
# O mais utilizado é o K-Médias.
#
# ### Redução de Dimensão
#
# Tem como objetivo reduzir o número de variáveis, atributos ou características dos modelos.
#
# No caso de algoritmos de negociação, com diversos indicadores e variáveis financeiras, poderíamos aplicar a redução para diminuir o número de variáveis sem que ocorra a perca de informação.
#
# O algoritmo de redução mais utilizado é a análise de componentes principais.
#
# ## Trading Ativo
#
# Busca negociação de curto prazo.
#
# Os modelos mais utilizados de machine learning são modelos supervisionados de classificação.
#
# Dado que a compra ou venda é uma decisão binária, pode-se associar essa decisão ao modelo de classificação, utilizando os indicadores técnicos e histórico de preços, treina-se os algoritmos de negociação para predizer se os preços subirão ou descerão.

# %% [markdown]
# # Principais Algoritmos de Negociação
#
# ## Máquinas de Suporte Vetorial (SVM)
#
# São um modelo de machine learning que buscam uma classificação linear ou não linear.
#
# O método baseia-se na maximização das margens de separação entre duas classes.
#
# \begin{equation}
# y = \{+1, -1\}
# \end{equation}
#
# Há uma função núcleo (Kernel) que maximiza a distância dos pontos de cada classe.
#
# ### Núcleo (Kernel)
#
# A função do núcleo pode ser não linear, sendo uma função:
# - Polinominal;
# - Gaussiana;
# - Exponencial;
# - Laplaciano;
# - Hiperbólico;
# - Base radial.
#
# A buscado núcleo ideal é o que define o sucesso do modelo.
#
# ## Árvores de Decisão
#
# São algortimos versáteis.
#
# Utilizam de divisões binárias recursivas para classificar as observações.
#
# ### Random Forest (busca aleátoria)
#
# É considerado o algortimo mais popular/poderoso de árvore de decisão.
#
# Gerados 500 amostras diferentes da amostra inicial, treina-se cada amostra com uma árvore de decisão e, por último, junta-se todas as árvores em uma só.
#
# A potência está no treino das subamostras.
#
# ## Redes Neurais (ANN)
#
# São algoritmos baseados no funcionamento do cérebro humano.
#
# Possuem três camadas:
# - Entrada: na qual recebem os dados;
# - Ocultas: em que os dados são processados;
# - Saída: enviam a informação ao exterior;
#
# No caso do trading ativo, podemos estruturar uma camada de entrada com indicadores técnicos, camadas ocultas para o processamento e uma última camada de saída com a informação se o preço sobe ou desce.
#
# # Qual utilizar?
#
# Para tomar a decisão, é necessário conhecer as métricas para avaliação de cada algoritmo.
#
# ## Conjuntos de Treino e Teste
#
# Refere-se a divisão que é necessária ser feita para avaliar o algoritmo.
#
# - **Conjunto de treino**: um subconjunto para treinar o modelo;
# - **Conjunto de teste**: um subconjunto para testar o modelo treinado;
#
# ## Avaliando o Desempenho
#
# Para a avaliação do desempenho do algoritmo, utiliza-se a **matriz de confusão**.
#
# ### Matriz de Confusão
#
# É uma ferramento que permite a visualização do desempenho de um algoritmo de confusão.
#
# |                  | Previu Venda -1             | Previu Compra      +1        |
# |------------------|-----------------------------|------------------------------|
# | **Venda Real (-1)**  | Verdadeiro Negativos (VN) | Falsos Positivos (FP)      |
# | **Compra Real (+1)** | Falsos Negativos (FN)     | Verdadeiros Positivos (VP) |
#
# A acurácia é uma medida para avaliar os modelos de classificação, é equivalente a proporção do número de predições corretas pelo total de predições.
#
# \begin{equation*}
# Acurácia = \frac{Número de Predições Corretas}{Total Predições}
# \end{equation*}
#
# Ou seja,
#
# \begin{equation*}
# Acurácia = \frac{VN + VP}{VN + FP + FN + VP}
# \end{equation*}
#
# Além disso, é possível definir ainda a precisão para cada uma das classificações
#
# \begin{equation*}
# Precisão (Compra) = \frac{VP}{VP + FP}
# \end{equation*}
#
# Por último, temos ainda o _recall_, que é a proporção real dos que foram identificados corretamente
# \begin{equation*}
# Recall = \frac{VP}{VP + FN}
# \end{equation*}
#
# ## Curva ROC (_Receiver Operating Characteristic Curve_)
#
# É um gráfico que mostra o rendimento de um algoritmo de classificação.
#
# A curva compara a taxa de verdadeiros positivos que busca-se maximizar e a taxa dee falsos positivos que busca-se minimizar:
# \begin{equation*}
# TPR = \frac{VP}{VP + FN}
# \end{equation*}
#
# ## AUC (_Area Under Curve ROC_)
#
# É uma medição agregada dos rendimentos em todos os cenários de classificação possíveis.
#
# O AUC oscila de 0 a 1, um modelo em que 100% das predições são corretas possuem AUC = 1.
#
# # Trading com base em ML
# É uma aplicação dos algoritmos e ferramentas de _machine learning_ para avaliar a compra ou venda de um ativo financeiro com base em indicadores técnicos (_features_).
#
#
# # Próximos passos...
# Os próximos para se aprofundar no trading com ML são:
# - Otimização dos hiperparâmetros: Consiste em encontrar os melhores parâmetros para se colocar nos modelos de ML;
#     - Número de árvores na random forest;
#     - Kernel na SVM;
#     - Profundidade das árvores de decisão;
#     - Arquitetura da rede neural.
#
# Os modelos são muitos sensíveis aos parâmetros, então podemos estender o conhecimento incluindo:
# - Outros ativos financeiros na análise;
# - Outros indicadores técnicos.

# %%
import numpy as np
import pandas as pd
import yfinance as yfin
import matplotlib.pyplot as plt
import mplfinance as mpf
import ta
import pandas_datareader as pdr

# Importa a função de dividir os dados entre treino e teste
from sklearn.model_selection import train_test_split

# Importa função para normalizar os dados de entrada de treino e teste
from sklearn.preprocessing import StandardScaler

# Importa função do algoritmos de ML
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import HistGradientBoostingClassifier as HGBC

# Importa funções para medir desempenho do algoritmo de ML
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
#from sklearn.metrics import plot_roc_curve
from sklearn.metrics import RocCurveDisplay

import warnings    
warnings.simplefilter("ignore")

# %% [markdown]
# ## Funções do último módulo...

# %%
def graficoEstrategia(df, shortMM, longMM):
    plt.figure(figsize = (20, 10))
    plt.plot(df['Close'], alpha = 0.6, label = 'Preços')

    plt.scatter(df.index, df['Compra'], color = 'green', marker = '^', label = 'Compra')
    plt.scatter(df.index, df['Venda'], color = 'crimson', marker = 'v', label = 'Venda')

    plt.title(f'Sinais de Compra e Venda, EMA {shortMM} & EMA {longMM}')
    plt.xlabel('Dia')
    plt.ylabel('Preço USD/bbl')
    plt.legend(loc = 'upper left')

    return plt


def graficoPatrimonio(ativo):
    plt.figure(figsize = (20, 10))
    plt.plot(ativo['Equity'])
    plt.title('Patrimônio - Estratégia de Médias Móveis Exponencias')
    plt.xlabel('Dia')
    plt.ylabel('Valor')
    plt.show()

def calculaParametros(df, risk_free):
    retornos = np.log(df['Equity']).diff().mean()
    retornos = retornos * 252
    #print(retornos)
    volatility = np.log(df['Equity']).diff().std()
    volatility = volatility * np.sqrt(252)
    #print(volatility)
    sharpe_ratio = (retornos - risk_free)/volatility
    saida = {
        'retornos': retornos,
        'sharpe': sharpe_ratio,
        'volatilidade': volatility
        
    }
    return saida
    
def estrategiaMediaMovel(ativo, inicio, fim, intervalo, shortMM, longMM):
    def algoritmo(dfTemp):
        n = len(dfTemp)       
        sinais = [0]

        for i in range(1, n):
            short = dfTemp['EMA_short'][i]
            long = dfTemp['EMA_long'][i]

            previous_short = dfTemp['EMA_short'][i-1]
            previous_long = dfTemp['EMA_long'][i-1]

            if previous_short < previous_long and short >= long:
                sinais.append(1)

            elif previous_short > previous_long and short <= long:
                sinais.append(-1)

            else:
                sinais.append(0)

        dfTemp['Sinais'] = sinais
        dfTemp['Compra'] = np.where(dfTemp['Sinais'] == 1, dfTemp['Close'], np.nan)
        dfTemp['Venda'] = np.where(dfTemp['Sinais'] == -1, dfTemp['Close'], np.nan)
        
        return dfTemp
        


    df = yfin.download(ativo, inicio, fim, interval = intervalo)
    df = df.dropna()
    df['EMA_short'] = df['Close'].ewm(span =shortMM, adjust = False).mean()
    df['EMA_long'] = df['Close'].ewm(span = longMM, adjust = False).mean()
    
    df = algoritmo(df)
    #resultado = grafico(df, shortMM, longMM)
    
    return df#, grafico
    
def backtestEstrategia(ativo, equity, TP, SL):
    '''Backtesting: Retorna o DataFrame com a variação de patrimônio, retorno, volatilidade e sharpe ratio da estratégia'''   
    
    N = len(ativo)
    equity = [equity]

    # Take Profit (lucro/stop gain) TP
    # Stop Loss SL

    pos = 0

    for i in range(1, N):

        equity.append(equity[i-1])

        if pos == 1:
            if ativo['Close'][i] >= preco*(1 + TP):
                pos = 0
                equity[i] *= (1 + TP)

            elif ativo['Close'][i] <= preco*(1 - SL):
                pos = 0
                equity[i] *= (1 - SL)


        elif pos == -1:
            if ativo['Close'][i] <= preco*(1 - TP):
                pos = 0
                equity[i] *= (1 + TP)

            elif ativo['Close'][i] >= preco*(1 + SL):
                pos = 0
                equity[i] *= (1 - SL)


        else:
            if ativo['Sinais'][i] != 0:
                pos = ativo['Sinais'][i]
                preco = ativo['Close'][i]
        #print(equity)   

    ativo['Equity'] = equity
    
    

    return ativo

# %% [markdown]
# ## Funções desse módulo...

# %%
def indicadoresTecnicos(df, listaMM):
    '''Gera as colunas com os dados dos indicadores técnicos baseados em um dataframe e uma lista de médias móveis'''
    # Definindo as médias móveis pelo preço do ativo para identificar se está acima ou abaixo
    for mm in listaMM:
        df[f'EMA_{mm}'] = ta.trend.ema_indicator(close = df['Close'], window = mm, fillna = True)/df['Close']
    
    # Índice de Força Relativa (RSI) 
    df['RSI'] = ta.momentum.rsi(close = df['Close'], fillna = True)
    
    # Alcance Médio Real (ATR)
    df['ATR'] =  ta.volatility.average_true_range(high = df['High'], low = df['Low'], close = df['Close'], fillna = True)
    
    # Williams Percent Range
    df['WR'] = ta.momentum.williams_r(high = df['High'], low = df['Low'], close = df['Close'], fillna = True)
    
#     df = ta.add_all_ta_features(
#         df, open="Open", high="High", low="Low", close="Close", volume="Volume", fillna=True)

    
    return df

def tratandoDF(df):
    '''Adiciona uma coluna target com a info de compra ou venda e ajusta o DF dropando algumas linhas nas quais os indicadores não foram calculados'''
    # Criando um vetor em target para definir com base nos preços de fechamento se o preço de encerramento foi maior ou menor que o anterior
    cl = np.array(df['Close'])
    target = np.where(cl[1:] > cl[0:-1], 1, -1)
    # Como não teremos o preço da última linha, podemos dropa-la
    df.drop(df.tail(1).index, inplace = True)
    df['Target'] = target
    
    # Eliminando linhas que não possuem alguns dados para indicadores técnicos
    df.drop(df.head(29).index, inplace = True)
    
    
    return df


def matrizEntradaSaida(df):
    '''Gera as matrizes de dados de entrada e saída com base no recorte dos indicadores e do campo alvo (venda ou compra)'''
    # Precisamos construir uma matriz que contenha os dados dos indicadores técnicos que geramos
    X = np.array(df.iloc[:, 6:-1]) 

    # Também construímos um vetor que contém as variáveis de saída
    Y = np.array(df['Target'])
    
    return X, Y

def organizaTesteTreino(matrizEntrada, matrizSaida, testSize):
    '''Organiza os dados de teste e treino, também normaliza os indicadores. Retorna um dicionário'''    
    X_train, X_test, Y_train, Y_test = train_test_split(matrizEntrada, matrizSaida, test_size = testSize, shuffle = False)
    ss = StandardScaler()
    ss = ss.fit(X_train)
    X_train = ss.transform(X_train)
    X_test = ss.transform(X_test)
    dados = {
        'entradaTreino': X_train,
        'entradaTeste': X_test,
        'saidaTreino': Y_train,
        'saidaTeste': Y_test
    }
    
    return dados



def classificador(algoritmo, dados):
    '''Dado um algoritmoe e os dados, a função treina o algoritmo com base nos dados e gera as métricas'''
    algoritmo = algoritmo.fit(dados['entradaTreino'], dados['saidaTreino'])
    predicao = algoritmo.predict(dados['entradaTeste'])
    
    accScore = accuracy_score(dados['saidaTeste'], predicao)
    confMatrix = confusion_matrix(dados['saidaTeste'], predicao)
    
    saida = {
        'predicao': predicao,
        'metricas':{
            'acuracia': accScore,
            'confusao': confMatrix
        }        
    }
    return saida

def ajustaSinaisDF(df, dados, clf):
    '''Ajusta a coluna de sinais de compra ou venda do DF baseado no retorno do classificador de ML'''
    N = len(dados['saidaTeste'])
    df = df.tail(N)
    df['Sinais'] = clf['predicao']
    return df


def TradingComMachineLearning(infoAtivo, infoTecnica, infoBacktest):
    df = yfin.download(infoAtivo['ativo'], infoAtivo['inicio'], infoAtivo['fim'], interval = infoAtivo['intervalo'])
    df = indicadoresTecnicos(df, infoTecnica['listaMedias'])
    df = tratandoDF(df)
    X, Y = matrizEntradaSaida(df)
    dados = organizaTesteTreino(X, Y, infoTecnica['pesoTeste'])
    resClassif = classificador(infoTecnica['algoritmoClassificador'], dados)
    dfComSinais = ajustaSinaisDF(df, dados, resClassif)
    backtest = backtestEstrategia(dfComSinais, infoBacktest['equity'], infoBacktest['takeProfit'], infoBacktest['stopLoss'])
    saida = {
        'Estrategia': infoTecnica['estrategia'],
        'Informacoes': df,
        'Sinais': dfComSinais,
        'Backtest': backtest,
        'DesempenhoClassificador': resClassif,
        'Dados': dados,
        'Algoritmo': infoTecnica['algoritmoClassificador']
    }
    return saida

# %%
#listaMedias = [5, 20, 30, 50, 100]
listaMedias = [3, 5, 8, 13, 21] # fibonacci
pesoTeste = 0.1
infoAtivo = {
    'ativo': 'PETR4.SA',
    'inicio': '2002-01-19',
    'fim': '2023-07-10',
    'intervalo': '1d'
}
infoBacktest ={
    'equity': 100,
    'takeProfit': 0.03,
    'stopLoss': 0.01
}
infoTecnicaRF = {
    'estrategia': 'Random Forest',
    'listaMedias': listaMedias,
    'pesoTeste': pesoTeste,
    'algoritmoClassificador': RandomForestClassifier(n_estimators = 300)    
}
infoTecnicaSVM = {
    'estrategia': 'SVM',
    'listaMedias': listaMedias,
    'pesoTeste': pesoTeste,
    'algoritmoClassificador': SVC()    
}
infoTecnicaMLPC = {
    'estrategia': 'Rede Neural',
    'listaMedias': listaMedias,
    'pesoTeste': pesoTeste,
    'algoritmoClassificador': MLPClassifier(hidden_layer_sizes = (64, 32), max_iter = 1000)
}

ativoSVM = TradingComMachineLearning(infoAtivo, infoTecnicaSVM, infoBacktest)
ativoRF = TradingComMachineLearning(infoAtivo, infoTecnicaRF, infoBacktest)
ativoMLPC = TradingComMachineLearning(infoAtivo, infoTecnicaMLPC, infoBacktest)

print('Concluído')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Concluído

# %%
comp_estrategias = [ativoSVM, ativoMLPC, ativoRF]
for est in comp_estrategias:
    parametros = calculaParametros(est['Backtest'], 0.1)
    print(f"Estratégia {est['Estrategia']}")
    print(f"Sharpe ratio: {round(parametros['sharpe'], 2)}, Retornos: {round(parametros['retornos'] * 100, 2)}%, Volatilidade: {round(parametros['volatilidade'] * 100, 2)}%\n")
# Out:
# Estratégia SVM
# Sharpe ratio: 1.69, Retornos: 38.64%, Volatilidade: 16.95%
#
# Estratégia Rede Neural
# Sharpe ratio: 1.29, Retornos: 31.19%, Volatilidade: 16.41%
#
# Estratégia Random Forest
# Sharpe ratio: 2.57, Retornos: 55.46%, Volatilidade: 17.72%

# %%
#ativoRF['Informacoes']

# %%
tickerComp1 = '^BVSP'
tickerComp2 = '^GSPC'

compAtivo1 = yfin.download(tickerComp1, ativoRF['Backtest'].index[0], ativoRF['Backtest'].index[-1])
compAtivo2 = yfin.download(tickerComp2, ativoRF['Backtest'].index[0], ativoRF['Backtest'].index[-1])
compAtivo1['Equity'] = (100/compAtivo1['Close'][0]) * compAtivo1['Close']
compAtivo2['Equity'] = (100/compAtivo2['Close'][0]) * compAtivo2['Close']

legenda = []
plt.figure(figsize = (20, 10))
for est in comp_estrategias:
    if est['Estrategia'] == 'Random Forest':
        plt.plot(est['Backtest']['Equity'], color = 'forestgreen')
    else:
        plt.plot(est['Backtest']['Equity'])
    legenda.append(f"{infoAtivo['ativo']} - {est['Estrategia']}")

plt.plot(compAtivo1['Equity'], color = 'navy')
plt.plot(compAtivo2['Equity'], color = 'crimson')
legenda.append(tickerComp1)
legenda.append(tickerComp2)
plt.title(f"Patrimônio {infoAtivo['ativo']} - Estratégia com Machine Learning")
plt.legend(legenda, fontsize = 15)
plt.xlabel('Dia')
plt.ylabel('Valor')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
for est in comp_estrategias:
    #plot_roc_curve(est['Algoritmo'], est['dados']['entradaTeste'], est['dados']['saidaTeste'])
    RocCurveDisplay.from_predictions(est['Dados']['saidaTeste'], est['DesempenhoClassificador']['predicao'], name = est['Estrategia']) # Sem o warning

# %% [markdown]
# ## Exemplo Ethereum

# %%
inicio =  '2019-09-01'
fim = '2021-09-02'
intervalo = '1d'
df = yfin.download('ETH-USD', inicio, fim)
# df['Close t-1'] = df['Close'].shift(1)
# df['Returns'] = (df['Close'] - df['Close t-1'])/df['Close']
# df['Log Returns'] = np.log(df['Close']) - np.log(df['Close t-1'])
# retLogDia = np.mean(df['Log Returns'])
# retLogAno = retLogDia * 252

# volLogDia = np.std(df['Log Returns'])
# volLogAnual = volLogDia * np.sqrt(252)
df['Adj Close t-1'] = df['Adj Close'].shift(1)
df['Returns'] = (df['Adj Close'] - df['Adj Close t-1'])/df['Adj Close']
df['Log Returns'] = np.log(df['Adj Close']) - np.log(df['Adj Close t-1'])
retLogDia = np.mean(df['Log Returns'])
retLogAno = retLogDia * 252

volLogDia = np.std(df['Log Returns'])
volLogAnual = volLogDia * np.sqrt(252)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
round(volLogAnual*100, 2)
# Out:
# 84.83

# %%
retLogAno
# Out:
# 1.0709283810929227

# %%
# Transformando o gráfico em um diagrama de velas japonesas (candlesticks)
mpf.plot(
    df[-63:],    
    type = 'candle',
    volume = True,
    figratio = (16,8),
    style = 'yahoo',
    title = 'Ethereum Candlesticks'
)

# %%
shortMM = 5
longMM = 20
ativo = 'ETH-USD'
dfEstrategia = estrategiaMediaMovel(ativo, inicio, fim, intervalo, shortMM, longMM)
dfEstrategia = backtestEstrategia(dfEstrategia, 100, 0.03, 0.01) # ESTRATEGIA
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dfEstrategia['2020-01-01': '2020-01-30']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-01  129.630661  132.835358  129.198288  130.802002  130.802002
# 2020-01-02  130.820038  130.820038  126.954910  127.410179  127.410179
# 2020-01-03  127.411263  134.554016  126.490021  134.171707  134.171707
# 2020-01-04  134.168518  136.052719  133.040558  135.069366  135.069366
# 2020-01-05  135.072098  139.410202  135.045624  136.276779  136.276779
# 2020-01-06  136.305542  144.328186  136.079636  144.304153  144.304153
# 2020-01-07  144.311996  145.001770  140.488876  143.543991  143.543991
# 2020-01-08  143.487823  146.828003  138.268204  141.258133  141.258133
# 2020-01-09  141.155777  141.393982  136.236404  138.979202  138.979202
# 2020-01-10  138.967041  144.167328  135.520401  143.963776  143.963776
# 2020-01-11  143.409103  146.480911  142.207962  142.927109  142.927109
# 2020-01-12  143.032547  146.145859  142.707642  145.873932  145.873932
# ...

# %%
plt.figure(figsize = (20, 10))
plt.plot(dfEstrategia['Close'], alpha = 0.6, label = 'Preços')

plt.scatter(dfEstrategia.index, dfEstrategia['Compra'], color = 'green', marker = '^', label = 'Compra')
plt.scatter(dfEstrategia.index, dfEstrategia['Venda'], color = 'crimson', marker = 'v', label = 'Venda')

plt.title('Sinais de Compra e Venda, EMA 5 & EMA 20')
plt.xlabel('Dia')
plt.ylabel('Preço USD/bbl')
plt.legend(loc = 'upper left')

plt.show()

# %%
sp = yfin.download('^GSPC', '2019-09-01','2021-09-02')
btc = yfin.download('BTC-USD', '2019-09-01','2021-01-02')
dji = yfin.download('^DJI', '2019-09-01','2021-01-02')
dji['Equity'] = (100/dji['Close'][0]) * dji['Close']
btc['Equity'] = (100/btc['Close'][0]) * btc['Close']
sp['Equity'] = (100/sp['Close'][0]) * sp['Close']
df['Equity'] = (100/df['Close'][0]) * df['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize = (20, 10))
plt.plot(df['Equity'], color = 'darkblue')
plt.plot(sp['Equity'], color = 'darkred')
#plt.plot(btc['Equity'], color = 'goldenrod')
#plt.plot(dji['Equity'], color = 'red')
plt.title('Patrimônio - Comparação Ethereum e S&P 500')
plt.xlabel('Dia')
plt.ylabel('USD $')
plt.legend(['Ethereum', 'S&P 500'])
plt.show()

# %%
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-09-01   172.458405   173.696854   169.531281   171.629425   171.629425
# 2019-09-02   171.697601   180.145218   170.451691   178.347351   178.347351
# 2019-09-03   178.357758   182.347992   175.970169   179.499329   179.499329
# 2019-09-04   179.491989   180.136597   175.325363   175.992889   175.992889
# 2019-09-05   175.966278   176.163910   171.746826   174.217133   174.217133
# ...                 ...          ...          ...          ...          ...
# 2021-08-28  3275.104492  3284.845947  3217.403564  3244.403320  3244.403320
# 2021-08-29  3246.770996  3283.235596  3158.840332  3227.002686  3227.002686
# 2021-08-30  3227.192627  3346.581055  3151.444580  3224.374268  3224.374268
# 2021-08-31  3227.758057  3466.992188  3195.216553  3433.732666  3433.732666
# 2021-09-01  3430.762451  3836.867432  3387.408447  3834.828125  3834.828125
#
# ...

# %%
mpf.plot(
    df['2021-3-1':'2021-09-02'],
    type = 'candle',
    volume = True,
    style = 'yahoo',
    figsize = (20, 10),
    title = 'Ethereum Candlesticks',
    mav =  (5, 20)
)

# %% [markdown]
# ## Scripts antes transformar tudo em função...

# %%
df = yfin.download('BTC-USD', '2016-01-01', '2021-01-02')
df = indicadoresTecnicos(df, [5, 20, 50, 100])
df = tratandoDF(df)
X, Y = matrizEntradaSaida(df)
dados = organizaTesteTreino(X, Y, 0.1)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
svc = classificador(SVC(), dados)
dtc = classificador(DecisionTreeClassifier(), dados)
rfc = classificador(RandomForestClassifier(), dados)
mlp = classificador(MLPClassifier(hidden_layer_sizes = (64, 32), max_iter = 1000), dados)

# %% [markdown]
# #### Observação
# O Classificador MLP precisa do número de camadas ocultas e adicionalmente é necessário alterar o máximo de iterações para 500 para não gerar um warning...

# %%
# Backtesting

clf = rfc

equity = [100]
N = len(dados['saidaTeste'])
df = df.tail(N)
df['Sinais'] = clf['predicao']
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_10520\4053306705.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sinais'] = clf['predicao']

# %%
algoritmosClass = [SVC(), DecisionTreeClassifier(), RandomForestClassifier(), MLPClassifier(hidden_layer_sizes = (64, 32), max_iter = 1000)]
resultados = []
for alg in algoritmosClass:
    resultados.append(classificador(alg, dados))
    RocCurveDisplay.from_predictions(dados['saidaTeste'], resultados[-1]['predicao']) # Sem o warning
    #plot_roc_curve(alg, dados['entradaTeste'], dados['saidaTeste'])

# %% [markdown]
# # Scripts antes de organizar as ideias

# %%
# SVM - Support Vector Machine
# Por padrão, utiliza um kernel radial
svc = SVC()
svc = svc.fit(dados['entradaTreino'], dados['saidaTreino'])
svc_pred = svc.predict(dados['entradaTeste'])
acc = accuracy_score(dados['saidaTeste'], svc_pred)
matrix = confusion_matrix(dados['saidaTeste'], svc_pred)
RocCurveDisplay.from_predictions(dados['saidaTeste'], svc_pred)
#plot_roc_curve(svc, dados['entradaTeste'], dados['saidaTeste'])

# %%
# Árvore de Decisão
dtc = DecisionTreeClassifier()
dtc = dtc.fit(dados['entradaTreino'], dados['saidaTreino'])
dtc_pred = dtc.predict(dados['entradaTeste'])
#metricas(dados['saidaTeste'], dtc_pred)
RocCurveDisplay.from_predictions(dados['saidaTeste'], dtc_pred)
#plot_roc_curve(dtc, dados['entradaTeste'], dados['saidaTeste'])
